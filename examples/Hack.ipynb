# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from IPython.core.display import HTML, display
from importlib import reload

# pandas options 
pd.set_option('max_rows', 50)
pd.set_option('max_columns', 30)
pd.set_option('display.max_colwidth', 150)

# matplotlib and plotting options 
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# seaborn options 
sns.set(context='paper', style='darkgrid', font='serif')
# sns.set(context='paper', style='ticks', font='serif')

# warnings
import warnings
# warnings.simplefilter('error')
# warnings.simplefilter('ignore')
import logging
logging.getLogger("matplotlib").setLevel(logging.CRITICAL)

# %%
# this file is in examples
from importlib import reload
import sys
sys.path.insert(0,'..')
import aggregate as agg

import aggregate.parser as parser
import aggregate.underwriter as trash

uw = trash.Underwriter(debug=False)

# %%
uw = agg.Underwriter(update=False, log2=11, create_all=True)

# %%
d = uw('agg A1 10 claims sev lognorm 20 cv 0.2 fixed')
d = uw('agg Test1 10 claims [20 30 40 50 70 100] xs 0 sev lognorm 20 cv 1.2 fixed')
d.easy_update(log2=11, bs=0.25)

# %%
df = d.density_df
# Out:
# C:\Users\steve\Anaconda3\envs\Working_Duplicate\lib\site-packages\pandas\core\series.py:856: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df.plot(subplots=True, figsize=(10,10), layout=(-1,3));

# %%
isplay(d.audit_df._repr_html_())
# Out:
# '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>name</th>\n      <th>limit</th>\n      <th>attachment</th>\n      <th>el</th>\n      <th>freq_1</th>\n      <th>sev_1</th>\n      <th>agg_m</th>\n      <th>agg_cv</th>\n      <th>agg_skew</th>\n      <th>emp_sev_1</th>\n      <th>emp_sev_cv</th>\n      <th>emp_agg_1</th>\n      <th>emp_agg_cv</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Test1</td>\n      <td>20</td>\n      <td>0</td>\n      <td>127.353</td>\n      <td>10</td>\n      <td>12.7353</td>\n      <td>127.353</td>\n      <td>0.160104</td>\n      <td>-0.0568342</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>N
# ...

# %%
groups = [['p', 'p_sev'], ['log_p', 'log_p_sev'],
         ['S', 'S_sev', 'epd'],
          ['e', 'exa', 'exlea', 'exgta', 'exeqa']]
for i, g in enumerate(groups):
    f = df[g].plot();
    plt.savefig(f'c:\\temp\\dm_{i}.svg')

# %%
f.save_fig('c:\\temp\\dm.pdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-64768ee3a170> in <module>
# ----> 1 f.save_fig('c:\\temp\\dm.pdf')
#
# AttributeError: 'AxesSubplot' object has no attribute 'save_fig'

# %%
# ?plt.savefig
# Out:
# Signature: plt.savefig(*args, **kwargs)
# Docstring:
# Save the current figure.
#
# Call signature::
#
#   savefig(fname, dpi=None, facecolor='w', edgecolor='w',
#           orientation='portrait', papertype=None, format=None,
#           transparent=False, bbox_inches=None, pad_inches=0.1,
#           frameon=None, metadata=None)
#
# The output formats available depend on the backend being used.
#
# Parameters
# ----------
#
# fname : str or PathLike or file-like object
#     A path, or a Python file-like object, or
#     possibly some backend-dependent object such as
#     `matplotlib.backends.backend_pdf.PdfPages`.
#
#     If *format* is not set, then the output format is inferred from
#     the extension of *fname*, if any, and from :rc:`savefig.format`
#     otherwise.  If *format* is set, it determines the output format.
#
#     Hence, if *fname* is not a path or has no extension, remember to
#     specify *format* to ensure that the correct backend is used.
#
# ...

# %%
hash('asdf')
# Out:
# 3803312100642103393

# %%
d
# Out:
# <aggregate.distr.Aggregate object at 0x0000014C7BE539A8> name: A1

# %%
f'asdf {abs(hash(d))}_9'
# Out:
# 'asdf 9223371947604290662_9'

# %%
d._repr_html_()
# Out:
# '<h3>Aggregate object: A1</h3>\nClaim count 10.00, fixed distribution<br>\nSeverity: lognorm distribution, unlimited<br>\nUpdated with bucket size 0.25 and log2 = 11<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>E(X)</th>\n      <th>Est E(X)</th>\n      <th>Err E(X)</th>\n      <th>CV(X)</th>\n      <th>Est CV(X)</th>\n      <th>Err CV(X)</th>\n      <th>Skew(X)</th>\n    </tr>\n    <tr>\n      <th>X</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>Sev</th>\n      <td>20.0</td>\n      <td>20</td>\n      <td>0</td>\n      <td>0.200000</td>\n      <
# ...

# %%
import sys

# %%
try:
    print(xx)
except:
    print(sys.exc_info()[1])
    print(sys.exc_info())
    print('error')
# Out:
# name 'xx' is not defined
# (<class 'NameError'>, NameError("name 'xx' is not defined"), <traceback object at 0x0000014C7F805288>)
# error

# %%
import os

# %%
print(os.getenv('HOME'))
# Out:
# None

# %%
import pathlib

# %%
f = pathlib.Path.home() / 'Documents/Adobe/'

# %%
try:
    f.glob('*.*')[1]
except:
    print( report('heelo') )
# Out:
# heelo
# <class 'TypeError'>
# 'generator' object is not subscriptable
# ...

# %%
def report(msg):
    return msg + '\n' + '\n'.join((str(i) for i in sys.exc_info()))

# %%
h2 = d.audit_df._repr_html_()
h1 = d.audit_df.style._repr_html_()

# %%
display(HTML(h1))
# Out:
# <style  type="text/css" >
# </style><table id="T_30c4f11a_1218_11ea_92d0_f06e0bdf8fa7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >limit</th>        <th class="col_heading level0 col2" >attachment</th>        <th class="col_heading level0 col3" >el</th>        <th class="col_heading level0 col4" >freq_1</th>        <th class="col_heading level0 col5" >sev_1</th>        <th class="col_heading level0 col6" >agg_m</th>        <th class="col_heading level0 col7" >agg_cv</th>        <th class="col_heading level0 col8" >agg_skew</th>        <th class="col_heading level0 col9" >emp_sev_1</th>        <th class="col_heading level0 col10" >emp_sev_cv</th>        <th class="col_heading level0 col11" >emp_agg_1</th>        <th class="col_heading level0 col12" >emp_agg_cv</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
display(HTML(h2))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>limit</th>
#       <th>attachment</th>
#       <th>el</th>
#       <th>freq_1</th>
#       <th>sev_1</th>
#       <th>agg_m</th>
#       <th>agg_cv</th>
#       <th>agg_skew</th>
#       <th>emp_sev_1</th>
#       <th>emp_sev_cv</th>
#       <th>emp_agg_1</th>
#       <th>emp_agg_cv</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Test1</td>
#       <td>20</td>
#       <td>0</td>
#       <td>127.353</td>
#       <td>10</td>
#       <td>12.7353</td>
#       <td>127.353</td>
#       <td>0.160104</td>
#       <td>-0.0568342</td>
#       <td>NaN</td>
# ...

# %%
df = d.density_df.loc[0:500:100]
df
# Out:
#         loss             p         p_sev      log_p  log_p_sev         F  \
# loss
# 0.0      0.0  8.737132e-04  4.757399e-07  -7.042758 -14.558395  0.000874
# 25.0    25.0  7.873674e-04  2.738755e-03  -7.146816  -5.900252  0.084145
# 50.0    50.0  6.769923e-04  1.274348e-02  -7.297851  -4.362736  0.157447
# 75.0    75.0  5.567824e-04  4.071185e-05  -7.493336 -10.108991  0.219102
# 100.0  100.0  4.390250e-04  2.469221e-03  -7.730954  -6.003853  0.268770
# 125.0  125.0  3.325973e-04  0.000000e+00  -8.008578       -inf  0.307177
# 150.0  150.0  2.425623e-04  0.000000e+00  -8.324252       -inf  0.335742
# 175.0  175.0  1.706022e-04  0.000000e+00  -8.676176       -inf  0.356214
# 200.0  200.0  1.159107e-04  0.000000e+00  -9.062691       -inf  0.370376
# 225.0  225.0  7.619113e-05  0.000000e+00  -9.482266       -inf  0.379849
# 250.0  250.0  4.852244e-05  0.000000e+00  -9.933484       -inf  0.385982
# 275.0  275.0  2.997833e-05  0.000000e+00 -10.415036       -inf  0.389834
# ...

# %%
def color_negative_red(value):
  """
  Colors elements in a dateframe
  green if positive and red if
  negative. Does not color NaN
  values.
  """

  if value < 0:
    color = 'red'
  elif value > 0:
    color = 'green'
  else:
    color = 'black'

  return 'color: %s' % color

# Set CSS properties for th elements in dataframe
th_props = [
  ('font-size', '11px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#6d6d6d'),
  ('background-color', '#f7f7f9')
  ]

# Set CSS properties for td elements in dataframe
td_props = [
  ('font-size', '11px')
  ]

# Set table styles
styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]


(df.style
    .format('{:.5g}')
    .set_table_styles(styles))
# Out:
# <style  type="text/css" >
#     #T_6f2edea4_1219_11ea_81f2_f06e0bdf8fa7 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7f7f9;
#     }    #T_6f2edea4_1219_11ea_81f2_f06e0bdf8fa7 td {
#           font-size: 11px;
# ...

# %%
def format_dataframe(df):
    # https://mode.com/example-gallery/python_dataframe_styling/#dataframe-styling

    # Set CSS properties for th elements in dataframe
    th_props = [
      ('font-size', '11px'),
      ('text-align', 'center'),
      ('font-weight', 'bold'),
      ('color', '#6d6d6d'),
      ('background-color', '#f7f7f9')
      ]
    
    # Set CSS properties for td elements in dataframe
    td_props = [
      ('font-size', '11px')
      ]
    
    # Set table styles
    styles = [
      dict(selector="th", props=th_props),
      dict(selector="td", props=td_props)
      ]
    
    return (df.style
        .format({ c: '{:.5g}' for c in )
        .set_table_styles(styles))._repr_html_()

# %%
display(HTML(format_dataframe(d.audit_df)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-481cfb7e40e1> in <module>
# ----> 1 display(HTML(format_dataframe(d.audit_df)))
#
# <ipython-input-54-c33ef26684a2> in format_dataframe(df)
#      24     return (df.style
#      25         .format('{:.5g}')
# ---> 26         .set_table_styles(styles))._repr_html_()
#
# ~\Anaconda3\envs\Working_Duplicate\lib\site-packages\pandas\io\formats\style.py in _repr_html_(self)
#     162         Hooks into Jupyter notebook rich display system.
#     163         """
# --> 164         return self.render()
#     165
#     166     @Appender(
#
# ~\Anaconda3\envs\Working_Duplicate\lib\site-packages\pandas\io\formats\style.py in render(self, **kwargs)
#     518         self._compute()
#     519         # TODO: namespace all the pandas keys
# --> 520         d = self._translate()
# ...

# %%
d.audit_df .select_dtypes(object)
# Out:
#         name    limit attachment       el freq_1    sev_1    agg_m    agg_cv  \
# 0      Test1       20          0  127.353     10  12.7353  127.353  0.160104
# 1      Test1       30          0  151.672     10  15.1672  151.672  0.201162
# 2      Test1       40          0  166.196     10  16.6196  166.196  0.231038
# 3      Test1       50          0  175.445     10  17.5445  175.445  0.253899
# 4      Test1       70          0  185.926     10  18.5926  185.926  0.286526
# 5      Test1      100          0  192.966     10  19.2966  192.966  0.316791
# mixed  Test1  51.6667          0  999.558     60  16.6593  999.558  0.108081
#
#         agg_skew
# 0     -0.0568342
# 1       0.118121
# 2       0.242329
# 3       0.342031
# 4       0.501529
# 5       0.685077
# mixed   0.254448

# %%
d.audit_df.dtypes
# Out:
# name           object
# limit          object
# attachment     object
# el             object
# freq_1         object
# sev_1          object
# agg_m          object
# agg_cv         object
# agg_skew       object
# emp_sev_1     float64
# emp_sev_cv    float64
# emp_agg_1     float64
# emp_agg_cv    float64
# dtype: object

# %%
# ?d.audit_df.select_dtypes
# Out:
# Signature: d.audit_df.select_dtypes(include=None, exclude=None)
# Docstring:
# Return a subset of the DataFrame's columns based on the column dtypes.
#
# Parameters
# ----------
# include, exclude : scalar or list-like
#     A selection of dtypes or strings to be included/excluded. At least
#     one of these parameters must be supplied.
#
# Returns
# -------
# DataFrame
#     The subset of the frame including the dtypes in ``include`` and
#     excluding the dtypes in ``exclude``.
#
# Raises
# ------
# ValueError
#     * If both of ``include`` and ``exclude`` are empty
#     * If ``include`` and ``exclude`` have overlapping elements
#     * If any kind of string dtype is passed in.
#
# Notes
# -----
# * To select all *numeric* types, use ``np.number`` or ``'number'``
# * To select strings you must use the ``object`` dtype, but note that
#   this will return *all* object dtype columns
# * See the `numpy dtype hierarchy
# ...

# %%
dir(d)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_careful_q',
#  '_cdf',
#  '_density_df',
#  '_linear_quantile_function',
#  '_pdf',
#  '_repr_html_',
#  '_spec',
#  'agg_cv',
#  'agg_density',
#  'agg_lang',
#  'agg_m',
#  'agg_skew',
#  'aggregate_keys',
#  'attachment',
#  'audit_df',
#  'beta_name',
#  'bs',
#  'careful_q',
#  'careful_tvar',
#  'cdf',
#  'delbaen_haezendonck_density',
#  'density_df',
#  'dh_agg_density',
#  'dh_sev_density',
#  'discretize',
#  'easy_update',
#  'emp_stats',
#  'en',
#  'entropy_fit',
#  'freq_a',
#  'freq_b',
#  'freq_moms',
#  'freq_name',
# ...

# %%
pd.concat((d.statistics_df.T, d.statistics_total_df.T), axis=1)
# Out:
#                        0            1            2            3            4  \
# name               Test1        Test1        Test1        Test1        Test1
# limit                 20           30           40           50           70
# attachment             0            0            0            0            0
# sevcv_param          1.2          1.2          1.2          1.2          1.2
# el               127.353      151.672      166.196      175.445      185.926
# prem                   0            0            0            0            0
# lr                     0            0            0            0            0
# freq_1                10           10           10           10           10
# freq_2               100          100          100          100          100
# freq_3              1000         1000         1000         1000         1000
# freq_m                10           10           10           10           10
# ...

# %%
# ?d.easy_update
# Out:
# Signature: d.easy_update(log2=13, bs=0, **kwargs)
# Docstring:
# Convenience function, delegates to update. Avoids having to pass xs.
#
#
# :param log2:
# :param bs:
# :param kwargs:  passed through to update
# :return:
# File:      c:\users\steve\documents\cloudstation\telos\python\aggregate_project\aggregate\distr.py
# Type:      method

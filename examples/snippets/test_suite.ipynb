# %% [markdown]
# # Test Suite
#
# Run site database `test_suite.agg`: interpret and build all objects.
#
# ## Provenance
#
# * Oct 2022 created new.

# %%
import aggregate as agg
from aggregate import pprint, tweedie_convert, Aggregate, LoggerManager
# dbuild = Underwriter(name='Debug', update=True, debug=True, log2=13)
# Out:
# time: 672 ms (started: 2022-10-26 09:56:05 +01:00)
# WARNING: 21 shift/reduce conflicts
# Parser debugging for UnderwritingParser written to C:\Users\steve\aggregate\parser\parser.out

# %%
# make our own Underwriter with no pre-loaded databases
build = agg.Underwriter(name='Test Suite', update=True, debug=False, log2=13)
build.logger_level(30)
build.read_database('test_suite')
build
# Out:
# <p><h3>Underwriter Test Suite</h3>
# Knowledge contains 107 programs. Run <code>build.list()</code> for a list. Run <code>build.describe(kind)</code> for more details on objects of kind (port, agg, sev, or distortion) and <code>build.programs</code> for a program listing.</p><p>Settings:
# <span style="color: red;">log2</span>: 13;
# <span style="color: red;">update</span>: True;
# <span style="color: red;">debug</span>: False; </p>
# time: 235 ms (started: 2022-10-26 09:56:06 +01:00)

# %%
# build.knowledge
# Out:
# time: 0 ns (started: 2022-10-26 09:56:07 +01:00)

# %%
ans, df = build.create_by_name('A.*[23]', plot=True)
# Out:
# <code>agg A.Basic02 dfreq [12] dsev [0 1]
# </code>
# <code>agg A.Basic03 dfreq [1 2 3] dsev [1 2 10]
# </code>
# time: 1.08 s (started: 2022-10-26 09:57:20 +01:00)

# %%
ans

# %%
df

# %%
build.describe()
